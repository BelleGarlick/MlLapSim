# %% [markdown]
# # Train model

# %%
import numpy as np
import os
from pathlib import Path

from lapsim.encoder.partition import Partition
from lapsim.logging.logger import NewLogger

from lapsim.normalisation import TransformNormalisation

BATCH_SIZE = 256
EPOCHS = 200
FORESIGHT = 120
SAMPLING = 4
NORMAL_SPACING = 10
CHECKPOINT_EVERY = 5
NORMALISATION_BOUNDS_PATH = f"bounds-{NORMAL_SPACING}.json"

DATA_PATH = Path(fr"../dataset/dataset/encoded-{NORMAL_SPACING}/train")

# This code currently assumes you have one validation partition. but should be easy to add more
VAL_DATA_PATH = Path(fr"../dataset/dataset/encoded-{NORMAL_SPACING}/val")

# For test data
SPLICED_DATA_PATH = Path(fr"../dataset/dataset/spliced-{NORMAL_SPACING}/real-test")
TEST_DATA_PATH = Path(fr"../dataset/dataset/encoded-{NORMAL_SPACING}/real-test")

TENSOR_CACHE_DIR = fr"/run/media/belle/Development/Tensors-120f-{NORMAL_SPACING}m"

TRAINING_PARTITIONS = [x for x in os.listdir(DATA_PATH) if x[0] != '.']
VALIDATION_PARTITIONS = [x for x in os.listdir(VAL_DATA_PATH) if x[0] != '.']
TEST_PARTITIONS = [x for x in os.listdir(TEST_DATA_PATH) if x[0] != '.']

# %%
bounds = TransformNormalisation()

if os.path.exists(NORMALISATION_BOUNDS_PATH):
    bounds = TransformNormalisation.load(NORMALISATION_BOUNDS_PATH)
    print("Existing bounds loaded.")

else:
    print("No bounds file found, calculating new ones.")
    partitions = os.listdir(DATA_PATH)

    for p in TRAINING_PARTITIONS:
        partition = Partition.load(DATA_PATH / p)
        bounds.extend(partition)

    bounds.save(NORMALISATION_BOUNDS_PATH)
    print("Finished calculating bounds.")

bounds.transform.method = "flat-window"
bounds.transform.foresight = FORESIGHT
bounds.transform.sampling = SAMPLING
# Out:
# Existing bounds loaded.

# %%
from torch.optim import NAdam
from torch.nn import HuberLoss
from lapsim.models.lapsim import LapSimModel
import torch


ls_model = LapSimModel(weights_path=None, bounds=bounds)
print("Params", ls_model.total_params)


loss = HuberLoss()
optimiser = NAdam(ls_model.model.parameters())

def tensor(x):
    return torch.tensor(x, dtype=torch.float32).to(ls_model.device)
# Out:
# Params 547418

# %%
from lapsim.evals.evaluation import Evaluation
from lapsim.evals import evals_suite


def batchify(count, n):
    indexes = np.array(list(range(count)))
    np.random.shuffle(indexes)

    batches = []
    for i in range((count // n) + 1):
        batch = indexes[i * n:(i + 1)*n]
        if len(batch) > 0:
            batches.append(batch)

    return batches


best_model_perf = None

new_logger = NewLogger("lapsim", run_name="test")

x, (y_pos, y_vel), vehicles = bounds.normalise_and_transform(
    Partition.load(DATA_PATH / TRAINING_PARTITIONS[0]),
    cache_tensor_prefix=f"{TENSOR_CACHE_DIR}/{0}",
    cores=8
)

val_x, (val_y_pos, val_y_vel), val_vehicles = bounds.normalise_and_transform(
    Partition.load(VAL_DATA_PATH / VALIDATION_PARTITIONS[0]),
    cache_tensor_prefix=f"{TENSOR_CACHE_DIR}/val",
    cores=8)

for epoch in range(EPOCHS):
    ls_model.model.train()
    for i, partition in enumerate(TRAINING_PARTITIONS):
        # Start preloading the next batch of data while model trains
        loader = bounds.async_load_and_normalise_partition(
            DATA_PATH / TRAINING_PARTITIONS[(i + 1) % len(TRAINING_PARTITIONS)],
            cache_tensor_prefix=f"{TENSOR_CACHE_DIR}/{i + 1}",
            cores=8)

        batches = batchify(x.shape[0], BATCH_SIZE)
        for batch_idx, batch in enumerate(batches):
            optimiser.zero_grad()

            pred_pos, pred_vel = ls_model.model(tensor(x[batch]), tensor(vehicles[batch]))

            pos_loss = loss(pred_pos, tensor(y_pos[batch]))
            vel_loss = loss(pred_vel, tensor(y_vel[batch]))
            total_loss = (2 * pos_loss + vel_loss) / 3
            total_loss.backward()
            optimiser.step()

            new_logger.log_training_data(
                epoch,
                batch=batch_idx,
                n_batches=len(batches),
                partition=i,
                position_loss=pos_loss.item(),
                velocity_loss=vel_loss.item(),
            )

        # Once preloaded has finished we can set it to the next x/y datums
        loader.join()
        x, (y_pos, y_vel), vehicles = loader.normalisation

    # Validation
    ls_model.model.eval()
    with torch.no_grad():
        batches = batchify(val_x.shape[0], BATCH_SIZE)
        for batch_idx, batch in enumerate(batches):
            val_pred_pos, val_pred_vel = ls_model.model(tensor(val_x[batch]), tensor(val_vehicles[batch]))
            pos_loss = loss(val_pred_pos, tensor(val_y_pos[batch]))
            vel_loss = loss(val_pred_vel, tensor(val_y_vel[batch]))

            new_logger.log_validation_data(
                epoch,
                batch=batch_idx,
                n_batches=len(batches),
                position_loss=pos_loss.item(),
                velocity_loss=vel_loss.item(),
            )

    current_val_loss = np.mean(new_logger.val_pos_loss)
    best_validation_reached = best_model_perf is None or current_val_loss < best_model_perf

    new_logger.flush(epoch)

    if best_validation_reached:
        torch.save(ls_model.model.state_dict(), "ls2.pt")
        torch.save(ls_model.model.optimiser.state_dict(), "ls2-optim.pt")
        best_model_perf = current_val_loss

    if (epoch + 1) % CHECKPOINT_EVERY == 0:
        results = evals_suite.run_evals_suite(ls_model, TEST_DATA_PATH, SPLICED_DATA_PATH)
        results = Evaluation.combine(results)

        print(
            "LapTime Error:",
            round(results.laptime.abs_error, 3),
            "Pos Error:",
            round(results.position.mean_absolute, 3),
            "Vel Error:",
            round(results.velocity.mean_absolute, 3)
        )

        new_logger.log_checkpoint(
            epoch,
            ls_model.model,
            (val_x[0], val_vehicles[0]),
            results
        )
# Out:
# Epoch: 1, Position Loss: 0.013346, Velocity Loss: 0.000391, Position Loss: 0.009527, Velocity Loss: 0.000157
# New best val loss: 0.009684757969807833
# 4009 - Indycar (source from 2006) - CN Shanghai International Circuit - East Handling Circuit 2.json                       n                                 LapTime Error: 3.257 Pos Error: 1.148 Vel Error: 2.588
# Epoch: 2, Position Loss: 0.011757, Velocity Loss: 0.000280, Position Loss: 0.010179, Velocity Loss: 0.000107
# Epoch: 3, Position Loss: 0.011551, Velocity Loss: 0.000266, Position Loss: 0.011073, Velocity Loss: 0.000178
# Epoch: 4, Position Loss: 0.011463, Velocity Loss: 0.000260, Position Loss: 0.010107, Velocity Loss: 0.000106
# Epoch: 5, Position Loss: 0.011432, Velocity Loss: 0.000260, Position Loss: 0.009766, Velocity Loss: 0.000108
# Epoch: 6, Position Loss: 0.011414, Velocity Loss: 0.000258, Position Loss: 0.010339, Velocity Loss: 0.000155
# ...
