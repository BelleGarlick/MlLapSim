# %% [markdown]
# # Testing

# %%
from lapsim.normalisation import TransformNormalisation
from lapsim.evals.evaluate import  evaluate, evaluate2, estimate_lap_time, calculate_optimal_positions, find_apexes
import webdataset as wd

FORESIGHT = 120
SAMPLING = 4
# NORMALISATION_BOUNDS_PATH = "bounds.json"
NORMALISATION_BOUNDS_PATH = "bounds-10.json"

DATESET = "/Users/belle/Developer/MlLapSim/dataset/spliced-again-10/lapsim-real-00.tar"

bounds = TransformNormalisation.load(NORMALISATION_BOUNDS_PATH)
bounds.transform.method = "flat-window"
bounds.transform.foresight = FORESIGHT
bounds.transform.sampling = SAMPLING

# %%
from lapsim.models.lapsim import LapSimModel
import webdataset
from lapsim.preprocessor.encoder import decode
import json
import numpy as np
import mlflow
import torch
import os
import mlflow

model = LapSimModel(
    "ls2.pt",
    bounds
)

os.environ["MLFLOW_TRACKING_URI"] = "http://192.168.0.180:5000"
model.model = mlflow.pytorch.load_model(
    "mlflow-artifacts:/1/models/m-b97f7f4faaac4b7daa80bcc0625b83a6/artifacts", 
    map_location=model.device
)

dataset = webdataset.WebDataset(DATESET)\
    .map(decode)
# Out:
# 2026/06/18 19:05:31 WARNING mlflow.pytorch: Stored model version '2.10.0+cu130' does not match installed PyTorch version '2.10.0'

# %%
# Run predictions
requests = list(dataset)
predictions = model.predict(requests)
pairs = list(zip(requests, predictions))
# Out:
# Donea Mx5 Mk3 - US Las Vegas Motor Speedway - Outfield North Road Course

# %%
errors = evaluate(pairs)

for key, value in errors.items():
    if "sorted" in key: 
        continue
        
    print(key, value)
# Out:
# laptime/mean 0.11545777
# laptime/mean-abs 1.0102487
# laptime/rmse 1.4422107
# laptime/percentile-25 0.31821442
# laptime/percentile-50 0.7185631
# laptime/percentile-75 1.3641968
# laptime/percentile-95 2.960228
# laptime/max 12.996666
# laptime-per-kilometer/mean 0.025701212
# laptime-per-kilometer/mean-abs 0.35980362
# laptime-per-kilometer/rmse 0.7784851
# laptime-per-kilometer/percentile-25 0.09335285
# laptime-per-kilometer/percentile-50 0.20786688
# laptime-per-kilometer/percentile-75 0.3993178
# laptime-per-kilometer/percentile-95 1.0409976
# laptime-per-kilometer/max 17.686674
# position/mean -0.074209735
# position/mean-abs 0.6882255
# position/rmse 1.2007737
# position/percentile-25 0.1141698
# position/percentile-50 0.3450779
# position/percentile-75 0.84489644
# position/percentile-95 2.5647783
# position/max 20.724813
# position/apex/mean 0.062435076
# position/apex/mean-abs 0.31835526
# position/apex/rmse 0.8019227
# position/apex/percentile-25 0.021695573
# position/apex/percentile-50 0.08475834
# position/apex/percentile-75 0.3050127
# position/apex/percentile-95 1.315601
# position/apex/max 15.17041
# position/normalised/mean -0.004975507
# position/normalised/mean-abs 0.057559505
# position/normalised/rmse 0.09345536
# position/normalised/percentile-25 0.0110206455
# position/normalised/percentile-50 0.03250879
# position/normalised/percentile-75 0.07503596
# position/normalised/percentile-95 0.20047662
# position/normalised/max 0.98259443
# velocity/mean -0.11177349
# velocity/mean-abs 1.2303289
# velocity/rmse 1.6723979
# velocity/percentile-25 0.4380226
# velocity/percentile-50 0.9368477
# velocity/percentile-75 1.6750488
# velocity/percentile-95 3.3671303
# velocity/max 16.879787
# velocity/apex/mean 0.023125675
# velocity/apex/mean-abs 1.3343769
# velocity/apex/rmse 1.8177952
# velocity/apex/percentile-25 0.474926
# velocity/apex/percentile-50 1.0138664
# velocity/apex/percentile-75 1.812315
# velocity/apex/percentile-95 3.6830711
# velocity/apex/max 16.446642

# %%
width_range = bounds.bounds.max_width - bounds.bounds.min_width

# %%
# Out:
# np.float32(-0.10226442)

# %%
# Out:
# array([-1., -1., -1., ...,  1.,  1.,  1.], shape=(1776188,), dtype=float32)

# %%
largest = 0, None

for track in dataset:
    track_max_width = np.max(track["widths"])
    if track_max_width > largest[0]:
        largest = track_max_width, track


# todo check the widths
# todo scan data to make sure no crosses

plot_full(
    tracks=[
        RenderItem(
            track=largest[1],
            label="Predicted",
            color="red"
        ),
    ],
    title="..."
)
plot_full(
    tracks=[
        RenderItem(
            track=pairs[0][1],
            label="Predicted",
            color="red"
        ),
    ],
    title="..."
)

# %%
best_tracks = [x[0] for x in errors["laptime-normalised/sorted"][:40]]
best_tracks
# Out:
# ['LMP1 - PT Autodromo Internacional do Algarve - Bike Circuit',
#  'V8 Supercars - BR Autodromo Internacional de Taruma - Stock Car Circuit',
#  'Formula E - AZ Kyalami - National Circuit',
#  'Generic GT3 - IT Vallelunga - International Motorcycle Circuit',
#  'V8 Supercars - UK Bedford Autodrome - SEN Circuit',
#  'Generic Ford Mustang 1965 - UK Cadwell Park - Club Circuit',
#  'Generic GT3 - RU Moscow Raceway - Grand Prix Circuit 2',
#  'LMP1 - US Indianapolis Motor Speedway - Motorcycle Road Course',
#  'Generic Group C - BR Cascavel - Autodromo Internacional Zilmar Beux',
#  'Generic GT3 - US Sonoma Raceway - Alternative Motorcycle Circuit',
#  'V8 Supercars - ES Circuit de Barcelona-Catalunya - Motorcycle National Circuit',
#  'Formula E - KW Kuwait Motor Town - South Circuit',
#  'Generic Ford Mustang 1965 - US Watkins Glen - Grand Prix Circuit',
#  'Generic LMP2 - RU Moscow Raceway - Short Circuit 6',
#  'Indycar (source from 2006) - BH Bahrain International Circuit - Inner Circuit',
#  'RoboRace - ES Circuit de Barcelona-Catalunya - Grand Prix Circuit',
#  'Indycar (source from 2006) - BR Autodromo Internacional de Taruma - Circuit Internacional',
#  'Indycar (source from 2006) - US Sebring - School Circuit',
#  'Generic Group C - AE Dubai Autodrome - Club Circuit',
#  'Generic GT3 - JP Okayama International Circuit - Piper Circuit',
#  'Formula E - AU Adelaide Street Circuit - Grand Prix Circuit',
#  'Formula E - AZ Kyalami - Grand Prix Circuit',
#  'Generic Group C - JP Okayama International Circuit - Piper Circuit',
#  'V8 Supercars - CN Zhuhai - Grand Prix Circuit',
#  'Porsche GT3 - UK Oulton Park - International Circuit',
#  'Generic GT3 - RU Moscow Raceway - Grand Prix Circuit 4',
#  'Mazda Mx5 Mk3 - RU Moscow Raceway - Grand Prix Circuit FIM',
#  'Generic GT3 - IT Imola - Motorcycle Circuit',
#  'Generic Group C - IT Mugello - Grand Prix Circuit',
#  'Formula E - BE Zolder - Grand Prix Circuit',
#  'Generic LMP2 - RU Fort Gronzy Autodrom - Alternative Circuit',
#  'Mazda Mx5 Mk3 - FR Le Mans - Maison Blanche Circuit 1',
#  'Generic Lola T70 Mk3B - BH Bahrain International Circuit - Outer Circuit',
#  'Generic LMP2 - RU Moscow Raceway - Grand Prix Circuit 8',
#  'Formula E - JP Fuji Speedway - Multipurpose Circuit',
#  'Generic GT3 - US Thunderhill Raceway Park - Three Mile Course',
#  'V8 Supercars - US Sonoma Raceway - Long Circuit',
#  'Generic Lola T70 Mk3B - RU Moscow Raceway - Short Circuit 7',
#  'Generic GT3 - CN Shanghai International Circuit - West Long Circuit',
#  'Generic LMP2 - IT Mugello - Grand Prix Circuit',
#  'RoboRace - RU Moscow Raceway - Short Circuit 5',
#  'Generic GT3 - DE Nurburgring - Sprint Circuit + Mercedes Arena',
#  'RoboRace - US Virginia International Raceway - North Course',
#  'Generic Group C - RU Fort Gronzy Autodrom - Full Circuit',
#  'Generic Group C - CN Shanghai International Circuit - Motorcycle Grand Prix Circuit',
#  'Generic Group C - US Sebring - School Circuit',
#  'Generic LMP2 - US Sonoma Raceway - Long Circuit',
#  'V8 Supercars - FR Le Mans - Bugatti Circuit',
#  'Porsche GT3 - JP Okayama International Circuit - Grand Prix Circuit',
#  'LMP1 - AU Bathurst Mount Panorama - Mount Panorama Circuit']

# %%
eval_pairs = [x for x in pairs if x[0]["id"] in best_tracks]

# %%
from lapsim.render import RenderItem, plot_full

for i, (input_record, output_record) in enumerate(eval_pairs):
    print(input_record["id"])
    plot_full(
        tracks=[
            RenderItem(
                track=output_record,
                label="Predicted",
                color="red"
            ),
            RenderItem(
                track=input_record,
                label="Ground Truth",
                color="green"
            ),
        ],
        title="..."
    )
# Out:
# Generic Group C - AE Dubai Autodrome - Club Circuit
# Formula E - AZ Kyalami - National Circuit
# Indycar (source from 2006) - BH Bahrain International Circuit - Inner Circuit
# V8 Supercars - UK Bedford Autodrome - SEN Circuit
# Generic GT3 - DE Nurburgring - Sprint Circuit + Mercedes Arena
# Generic GT3 - US Thunderhill Raceway Park - Three Mile Course
# V8 Supercars - BR Autodromo Internacional de Taruma - Stock Car Circuit
# Generic LMP2 - RU Moscow Raceway - Short Circuit 6
# Formula E - BE Zolder - Grand Prix Circuit
# RoboRace - US Virginia International Raceway - North Course
# LMP1 - US Indianapolis Motor Speedway - Motorcycle Road Course
# Generic LMP2 - RU Fort Gronzy Autodrom - Alternative Circuit
# Generic Group C - IT Mugello - Grand Prix Circuit
# RoboRace - ES Circuit de Barcelona-Catalunya - Grand Prix Circuit
# Generic LMP2 - US Sonoma Raceway - Long Circuit
# V8 Supercars - FR Le Mans - Bugatti Circuit
# Mazda Mx5 Mk3 - RU Moscow Raceway - Grand Prix Circuit FIM
# Indycar (source from 2006) - US Sebring - School Circuit
# Generic Ford Mustang 1965 - UK Cadwell Park - Club Circuit
# Generic LMP2 - RU Moscow Raceway - Grand Prix Circuit 8
# Generic GT3 - JP Okayama International Circuit - Piper Circuit
# Generic GT3 - CN Shanghai International Circuit - West Long Circuit
# Generic Lola T70 Mk3B - RU Moscow Raceway - Short Circuit 7
# Generic Ford Mustang 1965 - US Watkins Glen - Grand Prix Circuit
# Generic GT3 - IT Imola - Motorcycle Circuit
# Generic Group C - BR Cascavel - Autodromo Internacional Zilmar Beux
# Indycar (source from 2006) - BR Autodromo Internacional de Taruma - Circuit Internacional
# Generic GT3 - IT Vallelunga - International Motorcycle Circuit
# Generic Group C - CN Shanghai International Circuit - Motorcycle Grand Prix Circuit
# Generic Group C - JP Okayama International Circuit - Piper Circuit
# Formula E - AZ Kyalami - Grand Prix Circuit
# LMP1 - PT Autodromo Internacional do Algarve - Bike Circuit
# Generic Lola T70 Mk3B - BH Bahrain International Circuit - Outer Circuit
# Generic LMP2 - IT Mugello - Grand Prix Circuit
# Generic Group C - RU Fort Gronzy Autodrom - Full Circuit
# Mazda Mx5 Mk3 - FR Le Mans - Maison Blanche Circuit 1
# Porsche GT3 - UK Oulton Park - International Circuit
# Formula E - KW Kuwait Motor Town - South Circuit
# Generic Group C - US Sebring - School Circuit
# RoboRace - RU Moscow Raceway - Short Circuit 5
# Formula E - AU Adelaide Street Circuit - Grand Prix Circuit
# LMP1 - AU Bathurst Mount Panorama - Mount Panorama Circuit
# V8 Supercars - ES Circuit de Barcelona-Catalunya - Motorcycle National Circuit
# Porsche GT3 - JP Okayama International Circuit - Grand Prix Circuit
# Generic GT3 - RU Moscow Raceway - Grand Prix Circuit 4
# V8 Supercars - US Sonoma Raceway - Long Circuit
# Formula E - JP Fuji Speedway - Multipurpose Circuit
# Generic GT3 - US Sonoma Raceway - Alternative Motorcycle Circuit
# V8 Supercars - CN Zhuhai - Grand Prix Circuit
# Generic GT3 - RU Moscow Raceway - Grand Prix Circuit 2

# %%
from lapsim.evals.evaluation import Evaluation
import pandas as pd

# import pandas as pd
# from neural_simulator_toolkit.lapsim.models.evaluation import Evaluation

# filter out none apex errors as they currently result in an issue
evaluatable_comparisons = [x for x in evaluations if x.position.apex_mean is not None]

combined = Evaluation.combine(evaluatable_comparisons)

combined.print_string()

print()
# Out:
# Laptime
#  - Abs Error: 2.394697666168213
#  - Percentage: 2.6309382915496826
#  - Error per minute: 1.5785645246505737
# Position
#  - Max: 20.699701659016714
#  - Mean: -0.030244822133049482
#  - Mean Abs: 0.74319564199368
#  - RMSE: 1.1809111976910809
#  - Ci95: 2.6633193277577587
#  - Percentage Mean: 5.9819582780132805
#  - Percentage Max: 98.29288482666016
#  - Percentage Ci95: 20.200075149536133
#  - Apex Mean: -0.12948608258121216
#  - Apex Mean Abs: 0.38497902686598656
#  - Apex Max: 15.442739827175952
# Velocity
#  - Max: 16.812400817871094
#  - Mean: 0.5007168562672997
#  - Mean Abs: 1.3540727155363228
#  - RMSE: 1.7262331247329712
#  - Ci95: 3.4704015254974365
#  - Percentage Mean: 2.6948508175472736
#  - Percentage Max: 76.33523559570312
#  - Percentage Ci95: 6.813098430633545
#  - Apex Mean: 0.7390413430581588
#  - Apex Mean Abs: 1.5188676886135222
#  - Apex Max: 15.904006958007812

# %% [markdown]
# B## Combine Results
# This combines results together based on track/vehicle results

# %%
errors_by_track = {}
errors_by_vehicle = {}

for key, value, _, _ in evaluations:
    tokens = key.split(" - ")
    vehicle, track = tokens[0], " - ".join(tokens[1:])
    
    if track not in errors_by_track:
        errors_by_track[track] = []
    if vehicle not in errors_by_vehicle:
        errors_by_vehicle[vehicle] = []

    if value.position.apex_mean is not None:
        errors_by_track[track].append(value)
        errors_by_vehicle[vehicle].append(value)

for key in errors_by_vehicle:
    errors_by_vehicle[key] = Evaluation.combine(errors_by_vehicle[key])
for key in errors_by_track:
    errors_by_track[key] = Evaluation.combine(errors_by_track[key])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 errors_by_track = {}
#       2 errors_by_vehicle = {}
# ----> 4 for key, value, _, _ in evaluations:
#       5     tokens = key.split(" - ")
#       6     vehicle, track = tokens[0], " - ".join(tokens[1:])
#
# TypeError: cannot unpack non-iterable Evaluation object

# %%
def errors_to_df(errors):
    keys = list(errors)

    return pd.DataFrame({
        "Type": keys,
        "LapTime Error": [errors[x].laptime.abs_error for x in keys],
        "LapTime Percentage": [errors[x].laptime.percentage for x in keys],
        "LapTime Error Per Minute": [errors[x].laptime.error_per_minute for x in keys],

        "Position Error": [errors[x].position.mean_absolute for x in keys],
        "Position ci95": [errors[x].position.ci95 for x in keys],

        "Velocity Error": [errors[x].velocity.mean_absolute for x in keys],
        "Velocity ci95": [errors[x].velocity.ci95 for x in keys]
    })

vehicles_df = errors_to_df(errors_by_vehicle)
track_df = errors_to_df(errors_by_track)

# %%
track_df
